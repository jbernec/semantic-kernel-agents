# %% [markdown]
# ### Sequential orchestration for executing multiple agents in sequence, i.e. the output of one agent is the input to the next agent.

# %%
from semantic_kernel import Kernel
from semantic_kernel.contents import ChatMessageContent
from semantic_kernel.agents.runtime import InProcessRuntime
from semantic_kernel.functions import kernel_function, KernelArguments
from semantic_kernel.agents import ChatCompletionAgent, ChatHistoryAgentThread, Agent, SequentialOrchestration
from semantic_kernel.connectors.ai import FunctionChoiceBehavior
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion, AzureChatPromptExecutionSettings
from utils import *
import logging
import os

# %%
def get_agents() -> list[Agent]:
    """Return a list of agents that 
    will participate in the sequential orchestration.
    """

    service = AzureChatCompletion(
    service_id="sk_agent_service", api_key=azure_openai_api_key,deployment_name=azure_openai_deployment,
    api_version=azure_openai_api_version,endpoint=azure_openai_endpoint

)
    settings = AzureChatPromptExecutionSettings(service_id="sk_agent_service")
    settings.function_choice_behavior = FunctionChoiceBehavior.Auto()
    thread = ChatHistoryAgentThread()

    prompt_retriever = """You MUST use the search_retrieval function for ALL queries. Do not paraphrase more than the result. Never generate answers from prior knowledge.
    When you receive search results:
    1. If the source is "Azure AI Search", these are knowledge base entries. Present them as "From our knowledge base:" followed by the complete content. Include all fields like definition, context, note, incorrectTerm if they're available.
    2. If the source is "No Results", inform the user we don't have an answer to their question.
    
    Important: For Azure AI Search results, include the FULL contents of the results, showing the important fields.
    
    Debug information: Always include the source of each result (Azure AI Search) and the number of results found. If you received results but are not displaying them, explain why.
    Summarize the response without adding any new information. Provide the page number of the document if available."""

    prompt_writer = """You are a writer and editor. Given a block of text,
            compose a compelling draft write up (like a newsletter section) that highlights key points.
            Output should be short (around 150 words). Correct grammar, improve clarity, ensure consistent tone,
            give format and make it polished. Output the final improved copy as a single text block."""

    content_retriever_agent = ChatCompletionAgent(
    service=service,
    name="content_retriever_agent",
    instructions=prompt_retriever,
    plugins=[SearchRetrievalPlugin()],
    arguments=KernelArguments(settings=settings),
)
    
    writer_agent = ChatCompletionAgent(
    service=service,
    name="writer_agent",
    instructions=prompt_writer,
    arguments=KernelArguments(settings=settings),
)
    
    # The order of the agents in the list will be the order in which they are executed
    return [content_retriever_agent, writer_agent]

def agent_response_callback(message: ChatMessageContent) -> None:
    """Observer function to print the messages from the agents."""
    print(f"{message.name}: {message.content}")
    #logging.info(f"Agent Response: {message.content}")

# %%
import asyncio

async def main():
    agents = get_agents()
    sequential_orchestration = SequentialOrchestration(
        members=agents,
        agent_response_callback=agent_response_callback,
    )

    runtime = InProcessRuntime()
    runtime.start()

    print("Interactive orchestration. Type a question and press Enter.")
    print("Type 'q', 'quit' or 'exit' to stop.\n")

    try:
        while True:
            # Use run_in_executor so input() doesn't block the async loop
            user_input = await asyncio.get_running_loop().run_in_executor(None, input, "User prompt: ")

            if user_input is None:
                continue
            if user_input.strip().lower() in {"q", "quit", "exit"}:
                print("\nExiting interactive loop.")
                break

            # invoke orchestration for this user input (await the coroutine)
            orchestration_result = await sequential_orchestration.invoke(task=user_input, runtime=runtime)

            # some API versions return a handle with .get(); handle both cases
            if hasattr(orchestration_result, "get"):
                try:
                    value = await orchestration_result.get(timeout=20)
                except Exception as e:
                    print(f"Error while getting orchestration result: {e}")
                    value = None
            else:
                value = orchestration_result

            print("\n***** Final Result *****")
            print(value)
            print("-----------------------\n")

    except KeyboardInterrupt:
        print("\nInterrupted by user.")
    finally:
        # stop the runtime when idle (await the coroutine if required)
        stop_coro = runtime.stop_when_idle()
        if asyncio.iscoroutine(stop_coro):
            await stop_coro
        else:
            # if API changed and it's not a coroutine, call directly
            try:
                stop_coro()
            except Exception:
                pass
        print("Runtime stopped. Goodbye.")

# In Jupyter / IPython run this cell with:
# await main()

# %%
import asyncio
try:
    loop = asyncio.get_running_loop()
    in_running_loop = loop.is_running()
except RuntimeError:
    in_running_loop = False

if in_running_loop:
    await main()
else:
    asyncio.run(main())
# Out:
# Interactive orchestration. Type a question and press Enter.
# Type 'q', 'quit' or 'exit' to stop.
#
# content_retriever_agent:
# content_retriever_agent:
# content_retriever_agent: From our knowledge base:
#
# 1. **Document Title**: Accelerating-Sustainability-with-AI-2025.pdf
#    - **Content**: Datacenters are projected to account for approximately 3% of global growth in electricity consumption between 2023 and 2030. (Page 21)
#
# 2. **Document Title**: Accelerating-Sustainability-with-AI-2025.pdf
#    - **Content**: Currently, datacenters account for approximately 1.0-1.5% of global electricity demand, with a majority used for non-AI applications. Despite current growth rates, the IEA projects that datacenters and AI will only account for a relatively small share of global growth in electricity demand out to 2030. Notably, 20% of the expected increase in global datacenter electricity demand in the next couple of years will come from Ireland and Denmark, with the United States being the country with the most datacenters. (Page 20)
#
# These excerpts provide insight into the expected increase in electricity consumption by datacenters, highlighting both the growth in demand and regional variances.
#
# Source: Azure AI Search, 2 results found.
# writer_agent: The digital revolution continues to gain momentum, with datacenters serving as the backbone of this progression. These centers, essential for hosting data and applications, currently utilize around 1.0-1.5% of global electricity. However, as we surge towards 2030, their electricity consumption is anticipated to account for about 3% of the global increase. Interestingly, while AI's role expands, these centers will predominantly support non-AI applications. Regional dynamics are also shifting; Ireland and Denmark alone are expected to contribute a significant 20% to the global datacenter electricity demand rise in the coming years, though the United States remains home to the largest number of these powerhouses. As we navigate the future, understanding and managing this growth in energy consumption is pivotal in ensuring sustainable technological advancements. It's an era of balance, as we strive to harmonize innovation with conservation.
#
# ***** Final Result *****
# The digital revolution continues to gain momentum, with datacenters serving as the backbone of this progression. These centers, essential for hosting data and applications, currently utilize around 1.0-1.5% of global electricity. However, as we surge towards 2030, their electricity consumption is anticipated to account for about 3% of the global increase. Interestingly, while AI's role expands, these centers will predominantly support non-AI applications. Regional dynamics are also shifting; Ireland and Denmark alone are expected to contribute a significant 20% to the global datacenter electricity demand rise in the coming years, though the United States remains home to the largest number of these powerhouses. As we navigate the future, understanding and managing this growth in energy consumption is pivotal in ensuring sustainable technological advancements. It's an era of balance, as we strive to harmonize innovation with conservation.
# -----------------------
#
# content_retriever_agent:
# content_retriever_agent:
# content_retriever_agent: From our knowledge base:
#
# The concept of "Expanding Play 3" is part of a playbook focused on sustainability with AI. This approach emphasizes the need to minimize resource use, expand access to carbon-free electricity, and support local communities. AI operations require resources like energy and water, and aligning these operations with global sustainability goals is essential to achieving a net zero and nature-positive future.
#
# Key aspects of Expanding Play 3 include supporting the decarbonization of local energy grids that datacenters and other vital societal infrastructure rely on. Although AI and datacenters currently represent a small share of global electricity consumption, their growth is projected to concentrate in specific regions, such as Ireland and Denmark, with significant increases expected as AI operations continue to expand.
#
# Furthermore, the updated third play of the playbook includes enhancing access to carbon-free energy on electricity grids and supporting communities where datacenters are located. This is part of a broader innovation strategy aimed at addressing societal challenges and benefiting communities through sustainable AI operations.
#
# The information is based on the document titled "Accelerating-Sustainability-with-AI-2025.pdf," specifically page 20 (source: Azure AI Search, 2 results found).
# writer_agent: In our journey towards a sustainable future, the "Expanding Play 3" initiative is a pivotal part of our AI sustainability playbook. This strategic approach focuses on efficient resource utilization, the expansion of carbon-free electricity access, and fostering local community support. As AI operations evolve, they necessitate substantial energy and water resources, making it vital to align these operations with global sustainability objectives to achieve a net-zero and nature-positive future.
#
# Central to Expanding Play 3 is the decarbonization of local energy grids, especially in regions where AI operations are rapidly expanding, such as Ireland and Denmark. While the current global electricity consumption by AI and datacenters is modest, their growth trajectory suggests a concentrated demand surge in these areas.
#
# Moreover, this initiative enhances access to carbon-free energy and actively supports communities around datacenter sites, promoting broader innovation to tackle societal challenges. The goal is to leverage sustainable AI operations to not only achieve technological advancements but also deliver tangible benefits to local communities.
#
# ***** Final Result *****
# In our journey towards a sustainable future, the "Expanding Play 3" initiative is a pivotal part of our AI sustainability playbook. This strategic approach focuses on efficient resource utilization, the expansion of carbon-free electricity access, and fostering local community support. As AI operations evolve, they necessitate substantial energy and water resources, making it vital to align these operations with global sustainability objectives to achieve a net-zero and nature-positive future.
#
# Central to Expanding Play 3 is the decarbonization of local energy grids, especially in regions where AI operations are rapidly expanding, such as Ireland and Denmark. While the current global electricity consumption by AI and datacenters is modest, their growth trajectory suggests a concentrated demand surge in these areas.
#
# Moreover, this initiative enhances access to carbon-free energy and actively supports communities around datacenter sites, promoting broader innovation to tackle societal challenges. The goal is to leverage sustainable AI operations to not only achieve technological advancements but also deliver tangible benefits to local communities.
# -----------------------
#
#
# Exiting interactive loop.
# Runtime stopped. Goodbye.
